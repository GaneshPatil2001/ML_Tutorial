# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import r2_score

# %%
data= fetch_california_housing()

# %%
dataset = pd.DataFrame(data.data)

# %%
dataset.columns=data.feature_names
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
x=dataset
y=pd.DataFrame(data.target,columns=['target'])
y.columns=data.target_names

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.5, random_state=42)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5967   3.8929      19.0  4.974293   1.025707      1126.0  2.894602     34.10
# 17744  7.1267      15.0  6.932722   1.064220      1150.0  3.516820     37.29
# 952    5.0143      15.0  6.673196   1.058763      2484.0  2.560825     37.71
# 9361   8.3935      36.0  7.004792   0.990415      1549.0  2.474441     37.96
# 11024  4.8542      29.0  5.549618   0.900763       724.0  2.763359     33.79
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude
# 5967     -117.81
# 17744    -121.76
# 952      -121.94
# 9361     -122.53
# 11024    -117.83
# ...          ...
# 11284    -117.96
# 11964    -117.43
# 5390     -118.38
# 860      -121.96
# 15795    -122.42
#
# [10320 rows x 8 columns]

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[ 1.10548787e-02, -7.59595935e-01, -1.82275396e-01, ...,
#         -1.91039612e-02, -7.28203875e-01,  8.84404764e-01],
#        [ 1.70410990e+00, -1.07796450e+00,  5.78214594e-01, ...,
#          2.39421437e-02,  7.64217874e-01, -1.07903713e+00],
#        [ 5.98163512e-01, -1.07796450e+00,  4.77436452e-01, ...,
#         -4.21952097e-02,  9.60712274e-01, -1.16851043e+00],
#        ...,
#        [-4.90767508e-01,  5.93470476e-01, -5.65767285e-01, ...,
#          1.11607363e-02, -7.60952941e-01,  6.01072643e-01],
#        [ 9.67213695e-01, -1.07796450e+00,  3.69543887e-01, ...,
#          5.63660009e-04,  8.99892579e-01, -1.17845191e+00],
#        [-6.78669495e-01,  1.86694475e+00, -7.92598737e-01, ...,
#         -7.34742716e-02,  9.88782902e-01, -1.40710590e+00]],
#       shape=(10320, 8))

# %%
x_train=scaler.transform(x_test)

# %%
model=KNeighborsRegressor(n_neighbors=11).fit(x_train,y_train)

# %%
y_predict=model.predict(x_test)
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(

# %%
y_predict
# Out:
# array([[1.59436364],
#        [1.59436364],
#        [1.59436364],
#        ...,
#        [1.59436364],
#        [1.59436364],
#        [1.59436364]], shape=(10320, 1))

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.displot(y_predict-y_test,kind="kde")
plt.xlabel("Actual Value")
plt.ylabel("Predicted Value")
plt.show()
